# %% [markdown]
# [Download Dataset](https://www.kaggle.com/kaggle/sf-salaries)

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Salaries.csv')
data
# Out:
#           Id             EmployeeName  \
# 0          1           NATHANIEL FORD
# 1          2             GARY JIMENEZ
# 2          3           ALBERT PARDINI
# 3          4        CHRISTOPHER CHONG
# 4          5          PATRICK GARDNER
# ...      ...                      ...
# 78773  78774       Catheryn  Williams
# 78774  78775              Suan  Chang
# 78775  78776             Eric  Chiang
# 78776  78777               Alan  Lamb
# 78777  78778  Amalia  Barcena-Bosnich
#
#                                              JobTitle    BasePay  OvertimePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                     CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                     CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3                WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ...                                               ...        ...          ...
# 78773                                Registered Nurse  125164.01      4814.00
# 78774                                Registered Nurse  115008.19      5802.52
# 78775                                Police Officer 3  123528.19      8551.16
# 78776                                Police Officer 2  121068.01      5233.68
# 78777                                 Police Officer         NaN          NaN
#
#         OtherPay  Benefits   TotalPay  TotalPayBenefits    Year  Notes  \
# 0      400184.25       NaN  567595.43         567595.43  2011.0    NaN
# 1      137811.38       NaN  538909.28         538909.28  2011.0    NaN
# 2       16452.60       NaN  335279.91         335279.91  2011.0    NaN
# 3      198306.90       NaN  332343.61         332343.61  2011.0    NaN
# 4      182234.59       NaN  326373.19         326373.19  2011.0    NaN
# ...          ...       ...        ...               ...     ...    ...
# 78773     827.70  39224.45  130805.71         170030.16  2013.0    NaN
# 78774   10552.40  38667.00  131363.11         170030.11  2013.0    NaN
# 78775     871.97  37071.51  132951.32         170022.83  2013.0    NaN
# 78776    7137.39  36571.11  133439.08         170010.19  2013.0    NaN
# 78777        NaN       NaN        NaN               NaN     NaN    NaN
#
#               Agency  Status
# 0      San Francisco     NaN
# 1      San Francisco     NaN
# 2      San Francisco     NaN
# 3      San Francisco     NaN
# 4      San Francisco     NaN
# ...              ...     ...
# 78773  San Francisco     NaN
# 78774  San Francisco     NaN
# 78775  San Francisco     NaN
# 78776  San Francisco     NaN
# 78777            NaN     NaN
#
# [78778 rows x 13 columns]

# %% [markdown]
# ### 1.Display Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
# 5  118602.00      8601.00  189082.74       NaN  316285.74         316285.74
# 6   92492.01     89062.90  134426.14       NaN  315981.05         315981.05
# 7  256576.96         0.00   51322.50       NaN  307899.46         307899.46
# 8  176932.64     86362.68   40132.23       NaN  303427.55         303427.55
# 9  285262.00         0.00   17115.73       NaN  302377.73         302377.73
#
#      Year  Notes         Agency  Status
# 0  2011.0    NaN  San Francisco     NaN
# 1  2011.0    NaN  San Francisco     NaN
# 2  2011.0    NaN  San Francisco     NaN
# 3  2011.0    NaN  San Francisco     NaN
# 4  2011.0    NaN  San Francisco     NaN
# 5  2011.0    NaN  San Francisco     NaN
# 6  2011.0    NaN  San Francisco     NaN
# 7  2011.0    NaN  San Francisco     NaN
# 8  2011.0    NaN  San Francisco     NaN
# 9  2011.0    NaN  San Francisco     NaN

# %% [markdown]
# ### 2. Check Last 10 Rows of The Dataset

# %%
data.tail(10)
# Out:
#           Id             EmployeeName                    JobTitle    BasePay  \
# 78768  78769          Arthur M Howard            Police Officer 3  123471.01
# 78769  78770               Wei  Zhang  Traffic Signal Electrician  103480.01
# 78770  78771           Keith D Murphy              Police Officer  115945.52
# 78771  78772      Philip P Busalacchi            Police Officer 3  123471.09
# 78772  78773      Anthony M Inocencio            Police Officer 2  115363.80
# 78773  78774       Catheryn  Williams            Registered Nurse  125164.01
# 78774  78775              Suan  Chang            Registered Nurse  115008.19
# 78775  78776             Eric  Chiang            Police Officer 3  123528.19
# 78776  78777               Alan  Lamb            Police Officer 2  121068.01
# 78777  78778  Amalia  Barcena-Bosnich             Police Officer         NaN
#
#        OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits    Year  \
# 78768      4489.07   5034.11  37055.10  132994.19         170049.29  2013.0
# 78769     29026.03   3217.12  34315.73  135723.16         170038.89  2013.0
# 78770     11972.57   6509.01  35609.57  134427.10         170036.67  2013.0
# 78771      6416.50   3090.80  37055.20  132978.39         170033.59  2013.0
# 78772     14888.32   4921.71  34859.52  135173.83         170033.35  2013.0
# 78773      4814.00    827.70  39224.45  130805.71         170030.16  2013.0
# 78774      5802.52  10552.40  38667.00  131363.11         170030.11  2013.0
# 78775      8551.16    871.97  37071.51  132951.32         170022.83  2013.0
# 78776      5233.68   7137.39  36571.11  133439.08         170010.19  2013.0
# 78777          NaN       NaN       NaN        NaN               NaN     NaN
#
#        Notes         Agency  Status
# 78768    NaN  San Francisco     NaN
# 78769    NaN  San Francisco     NaN
# 78770    NaN  San Francisco     NaN
# 78771    NaN  San Francisco     NaN
# 78772    NaN  San Francisco     NaN
# 78773    NaN  San Francisco     NaN
# 78774    NaN  San Francisco     NaN
# 78775    NaN  San Francisco     NaN
# 78776    NaN  San Francisco     NaN
# 78777    NaN            NaN     NaN

# %% [markdown]
# ### 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (78778, 13)

# %%
print('Number of Rows', data.shape[0])
print('Number of columns', data.shape[1])
# Out:
# Number of Rows 78778
# Number of columns 13

# %% [markdown]
# ### 4. Getting Information About Our Dataset Like Total Number Rows,
# ### Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78778 entries, 0 to 78777
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                78778 non-null  int64
#  1   EmployeeName      78778 non-null  object
#  2   JobTitle          78778 non-null  object
#  3   BasePay           78777 non-null  float64
#  4   OvertimePay       78777 non-null  float64
#  5   OtherPay          78777 non-null  float64
#  6   Benefits          42618 non-null  float64
#  7   TotalPay          78777 non-null  float64
#  8   TotalPayBenefits  78777 non-null  float64
#  9   Year              78777 non-null  float64
#  10  Notes             0 non-null      float64
#  11  Agency            78777 non-null  object
#  12  Status            0 non-null      float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 7.8+ MB

# %% [markdown]
# ### 5.Check Null Values In The Dataset

# %%
data.isnull().sum()
# Out:
# Id                      0
# EmployeeName            0
# JobTitle                0
# BasePay                 1
# OvertimePay             1
# OtherPay                1
# Benefits            36160
# TotalPay                1
# TotalPayBenefits        1
# Year                    1
# Notes               78778
# Agency                  1
# Status              78778
# dtype: int64

# %% [markdown]
# ### 6. Drop ID, Notes, Agency and Status Columns

# %%
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
data = data.drop(['Id', 'Notes', 'Agency', 'Status'], axis=1)

# %%
data
# Out:
#                   EmployeeName  \
# 0               NATHANIEL FORD
# 1                 GARY JIMENEZ
# 2               ALBERT PARDINI
# 3            CHRISTOPHER CHONG
# 4              PATRICK GARDNER
# ...                        ...
# 78773       Catheryn  Williams
# 78774              Suan  Chang
# 78775             Eric  Chiang
# 78776               Alan  Lamb
# 78777  Amalia  Barcena-Bosnich
#
#                                              JobTitle    BasePay  OvertimePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                     CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                     CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3                WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ...                                               ...        ...          ...
# 78773                                Registered Nurse  125164.01      4814.00
# 78774                                Registered Nurse  115008.19      5802.52
# 78775                                Police Officer 3  123528.19      8551.16
# 78776                                Police Officer 2  121068.01      5233.68
# 78777                                 Police Officer         NaN          NaN
#
#         OtherPay  Benefits   TotalPay  TotalPayBenefits    Year
# 0      400184.25       NaN  567595.43         567595.43  2011.0
# 1      137811.38       NaN  538909.28         538909.28  2011.0
# 2       16452.60       NaN  335279.91         335279.91  2011.0
# 3      198306.90       NaN  332343.61         332343.61  2011.0
# 4      182234.59       NaN  326373.19         326373.19  2011.0
# ...          ...       ...        ...               ...     ...
# 78773     827.70  39224.45  130805.71         170030.16  2013.0
# 78774   10552.40  38667.00  131363.11         170030.11  2013.0
# 78775     871.97  37071.51  132951.32         170022.83  2013.0
# 78776    7137.39  36571.11  133439.08         170010.19  2013.0
# 78777        NaN       NaN        NaN               NaN     NaN
#
# [78778 rows x 9 columns]

# %% [markdown]
# ### 7. Get Overall Statistics About The Dataframe

# %%
data.describe()
# Out:
#              BasePay    OvertimePay       OtherPay      Benefits  \
# count   78777.000000   78777.000000   78777.000000  42618.000000
# mean    69878.083936    5701.249934    4246.949876  28640.709137
# std     44607.098174   12654.006941    8992.953853  15756.957332
# min      -166.010000       0.000000       0.000000      0.000000
# 25%     38631.030000       0.000000       1.410000  19423.420000
# 50%     66066.400000       0.000000    1040.000000  32770.910000
# 75%    102242.980000    5393.520000    5026.760000  38860.562500
# max    319275.010000  245131.880000  400184.250000  86533.210000
#
#             TotalPay  TotalPayBenefits          Year
# count   78777.000000      78777.000000  78777.000000
# mean    79826.283747      95320.777597   2011.615281
# std     53291.316784      64956.852894      0.620714
# min         0.000000          0.000000   2011.000000
# 25%     42473.630000      47867.910000   2011.000000
# 50%     73377.330000      89428.770000   2012.000000
# 75%    115703.460000     135340.820000   2012.000000
# max    567595.430000     567595.430000   2013.000000

# %%
data.describe(include='all')
# Out:
#        EmployeeName          JobTitle        BasePay    OvertimePay  \
# count         78778             78778   78777.000000   78777.000000
# unique        74074              2097            NaN            NaN
# top       Kevin Lee  TRANSIT OPERATOR            NaN            NaN
# freq              9              2388            NaN            NaN
# mean            NaN               NaN   69878.083936    5701.249934
# std             NaN               NaN   44607.098174   12654.006941
# min             NaN               NaN    -166.010000       0.000000
# 25%             NaN               NaN   38631.030000       0.000000
# 50%             NaN               NaN   66066.400000       0.000000
# 75%             NaN               NaN  102242.980000    5393.520000
# max             NaN               NaN  319275.010000  245131.880000
#
#              OtherPay      Benefits       TotalPay  TotalPayBenefits  \
# count    78777.000000  42618.000000   78777.000000      78777.000000
# unique            NaN           NaN            NaN               NaN
# top               NaN           NaN            NaN               NaN
# freq              NaN           NaN            NaN               NaN
# mean      4246.949876  28640.709137   79826.283747      95320.777597
# std       8992.953853  15756.957332   53291.316784      64956.852894
# min          0.000000      0.000000       0.000000          0.000000
# 25%          1.410000  19423.420000   42473.630000      47867.910000
# 50%       1040.000000  32770.910000   73377.330000      89428.770000
# 75%       5026.760000  38860.562500  115703.460000     135340.820000
# max     400184.250000  86533.210000  567595.430000     567595.430000
#
#                 Year
# count   78777.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean     2011.615281
# std         0.620714
# min      2011.000000
# 25%      2011.000000
# 50%      2012.000000
# 75%      2012.000000
# max      2013.000000

# %% [markdown]
# ### 8. Find Occurrence of The Employee Names  (Top 5)

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['EmployeeName'].value_counts().head(5)
# Out:
# Kevin Lee      9
# KEVIN LEE      9
# DAVID WONG     8
# RICHARD LEE    8
# Richard Lee    8
# Name: EmployeeName, dtype: int64

# %% [markdown]
# ### 9. Find The Number of Unique Job Titles

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['JobTitle'].nunique()
# Out:
# 2097

# %% [markdown]
# ### 10. Total Number of Job Titles Contain Captain

# %%
data[data['JobTitle'].str.contains('Captain')]
# Out:
#               EmployeeName                     JobTitle    BasePay  \
# 36167        John Goldberg                    Captain 3  104404.00
# 36180     Michael Rolovich    Captain, Fire Suppression  145659.03
# 36184        Darryl Hunter    Captain, Fire Suppression  145659.03
# 36186       Michael Delane    Captain, Fire Suppression  147069.71
# 36189       Philip Stevens    Captain, Fire Suppression  124573.50
# ...                    ...                          ...        ...
# 75050        Edwin R James            Sheriff's Captain  150713.41
# 75121     Michele D Fisher            Sheriff's Captain  150712.00
# 75308        Johna C Pecot            Sheriff's Captain  150294.70
# 75523   Elisabeth J Filiss  Captain, Emergency Med Svcs  149024.40
# 77591  Jeanine R Nicholson    Captain, Fire Suppression  129785.85
#
#        OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits    Year
# 36167         0.00  245999.41  24287.23  350403.41         374690.64  2012.0
# 36180    125868.06   30474.97  45129.03  302002.06         347131.09  2012.0
# 36184    115673.73   32610.00  49571.51  293942.76         343514.27  2012.0
# 36186    113372.94   33012.58  45978.15  293455.23         339433.38  2012.0
# 36189     53895.92  130200.40  28907.03  308669.82         337576.85  2012.0
# ...            ...        ...       ...        ...               ...     ...
# 75050      3686.83   12906.88  44812.55  167307.12         212119.67  2013.0
# 75121      2443.92   12906.51  44812.10  166062.43         210874.53  2013.0
# 75308         0.00   12872.77  44228.27  163167.47         207395.74  2013.0
# 75523         0.00   11674.20  43683.99  160698.60         204382.59  2013.0
# 77591         0.00   10692.82  39181.58  140478.67         179660.25  2013.0
#
# [267 rows x 9 columns]

# %%
len(data[data['JobTitle'].str.contains('Captain', case=False)])
# Out:
# 408

# %%
data[data['JobTitle'].str.contains('Captain', case=False)].count()
# Out:
# EmployeeName        408
# JobTitle            408
# BasePay             408
# OvertimePay         408
# OtherPay            408
# Benefits            267
# TotalPay            408
# TotalPayBenefits    408
# Year                408
# dtype: int64

# %% [markdown]
# ### 11. Display All the Employee Names From Fire Department

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['JobTitle'].str.contains('fire', case=False)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 78773    False
# 78774    False
# 78775    False
# 78776    False
# 78777    False
# Name: JobTitle, Length: 78778, dtype: bool

# %%
data[data['JobTitle'].str.contains('fire', case=False)]['EmployeeName']
# Out:
# 4             PATRICK GARDNER
# 6                   ALSON LEE
# 8              MICHAEL MORRIS
# 9          JOANNE HAYES-WHITE
# 10              ARTHUR KENNEY
#                  ...
# 78626    Theodore R Creighton
# 78627        George  Nonomura
# 78684      Manuel T Dacalanio
# 78698     Christopher M Blair
# 78749           Joshua B Hoyt
# Name: EmployeeName, Length: 4064, dtype: object

# %% [markdown]
# ### 12. Find Minimum, Maximum and Average BasePay

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['BasePay'].min()
# Out:
# -166.01

# %%
data['BasePay'].max()
# Out:
# 319275.01

# %%
data['BasePay'].mean()
# Out:
# 69878.0839363012

# %%
data['BasePay'].describe()
# Out:
# count     78777.000000
# mean      69878.083936
# std       44607.098174
# min        -166.010000
# 25%       38631.030000
# 50%       66066.400000
# 75%      102242.980000
# max      319275.010000
# Name: BasePay, dtype: float64

# %% [markdown]
# ### 13. Replace 'Not Provided' in EmployeeName' Column to NaN

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['EmployeeName'] = data['EmployeeName'].replace('Not Provided', np.nan)

# %%
data['EmployeeName']
# Out:
# 0                 NATHANIEL FORD
# 1                   GARY JIMENEZ
# 2                 ALBERT PARDINI
# 3              CHRISTOPHER CHONG
# 4                PATRICK GARDNER
#                   ...
# 78773         Catheryn  Williams
# 78774                Suan  Chang
# 78775               Eric  Chiang
# 78776                 Alan  Lamb
# 78777    Amalia  Barcena-Bosnich
# Name: EmployeeName, Length: 78778, dtype: object

# %% [markdown]
# ### 14. Drop The Rows Having 5 Missing Values

# %%
data[data.isnull().sum(axis=1)== 5]
# Out:
# Empty DataFrame
# Columns: [EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year]
# Index: []

# %% [markdown]
# ### 15. Find Job Title of ALBERT PARDINI

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data[data['EmployeeName'] == 'ALBERT PARDINI']['JobTitle']
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %% [markdown]
# ### 16. How Much ALBERT PARDINI Make (Include Benefits) ?

# %%
data[data['EmployeeName'] == 'ALBERT PARDINI']['TotalPayBenefits']
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ### 17. Display Name of The Person Having The Highest BasePay

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data[data['BasePay'].max() == data['BasePay']]['EmployeeName']
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %% [markdown]
# ### 18. Find Average BasePay of All Employee Per Year

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data.groupby('Year').mean()['BasePay']
# Out:
# <ipython-input-73-dc0d9c153096>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Year').mean()['BasePay']
# Year
# 2011.0     63595.956517
# 2012.0     65436.406857
# 2013.0    136600.254962
# Name: BasePay, dtype: float64

# %% [markdown]
# ### 19. Find Average BasePay of All Employee Per JobTitle

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data.groupby('JobTitle').mean('BasePay')
# Out:
#                                                      BasePay  OvertimePay  \
# JobTitle
# ACCOUNT CLERK                                   43300.806506   373.200843
# ACCOUNTANT                                      46643.172000     0.000000
# ACCOUNTANT INTERN                               28732.663958    24.430625
# ACUPUNCTURIST                                   66374.400000     0.000000
# ADMINISTRATIVE ANALYST                          63435.628602     0.000000
# ...                                                      ...          ...
# X-RAY LABORATORY AIDE                           47664.773077  3571.223462
# X-Ray Laboratory Aide                           48086.046452  3977.478387
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  52609.910000     0.000000
# Youth Comm Advisor                              57544.730000     0.000000
# ZOO CURATOR                                     43148.000000     0.000000
#
#                                                     OtherPay      Benefits  \
# JobTitle
# ACCOUNT CLERK                                     361.656988           NaN
# ACCOUNTANT                                        786.096000           NaN
# ACCOUNTANT INTERN                                 274.648333           NaN
# ACUPUNCTURIST                                    1220.000000           NaN
# ADMINISTRATIVE ANALYST                            519.238925           NaN
# ...                                                      ...           ...
# X-RAY LABORATORY AIDE                            1469.883846           NaN
# X-Ray Laboratory Aide                            1428.537419  22286.244516
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS   1022.960000           NaN
# Youth Comm Advisor                                  0.000000  28229.660000
# ZOO CURATOR                                     23538.560000           NaN
#
#                                                     TotalPay  \
# JobTitle
# ACCOUNT CLERK                                   44035.664337
# ACCOUNTANT                                      47429.268000
# ACCOUNTANT INTERN                               29031.742917
# ACUPUNCTURIST                                   67594.400000
# ADMINISTRATIVE ANALYST                          63954.867527
# ...                                                      ...
# X-RAY LABORATORY AIDE                           52705.880385
# X-Ray Laboratory Aide                           53492.062258
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  53632.870000
# Youth Comm Advisor                              57544.730000
# ZOO CURATOR                                     66686.560000
#
#                                                 TotalPayBenefits    Year
# JobTitle
# ACCOUNT CLERK                                       44035.664337  2011.0
# ACCOUNTANT                                          47429.268000  2011.0
# ACCOUNTANT INTERN                                   29031.742917  2011.0
# ACUPUNCTURIST                                       67594.400000  2011.0
# ADMINISTRATIVE ANALYST                              63954.867527  2011.0
# ...                                                          ...     ...
# X-RAY LABORATORY AIDE                               52705.880385  2011.0
# X-Ray Laboratory Aide                               75778.306774  2012.0
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS      53632.870000  2011.0
# Youth Comm Advisor                                  85774.390000  2012.0
# ZOO CURATOR                                         66686.560000  2011.0
#
# [2097 rows x 7 columns]

# %% [markdown]
# ### 20. Find Average BasePay of Employee Having Job Title ACCOUNTANT

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data[data['JobTitle'] == 'ACCOUNTANT']['BasePay'].mean()
# Out:
# 46643.172

# %% [markdown]
# ### 21. Find Top 5 Most Common Jobs

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['JobTitle'].value_counts().head()
# Out:
# TRANSIT OPERATOR    2388
# Transit Operator    2269
# Registered Nurse    1788
# Special Nurse       1468
# Police Officer 3    1423
# Name: JobTitle, dtype: int64
